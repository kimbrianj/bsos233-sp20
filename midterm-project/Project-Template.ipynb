# %% [markdown]
# # Project Template: The Title of the Midterm Project
#
# ## Introduction
#
# An introduction to the problem would go here. Motivate the problem. Why is this of interest?

# %% [markdown]
# ## Data Description
#
# You might use some data descriptives here. The data should be clear to anyone who has not looked at the dataset. For example, make sure you indicate how many people there are, how many people in different groups if that is important for your project, and summary statistics of the variables you are looking at.
#
# ### Political Affiliation and Scientists
#
# You can also have subheadings within each of your sections.

# %%
cah.pivot('Political Affiliation','Do you agree or disagree with the following statement: scientists are generally honest and are serving the public good. ')
# Out:
# Do you agree or disagree with the following statement: scientists are generally honest and are serving the public good.  | DK/REF | Democrat | Independent | Republican
# DK/REF                                                                                                                   | 3      | 2        | 2           | 1
# Neither Agree nor Disagree                                                                                               | 1      | 1        | 0           | 2
# Somewhat Agree                                                                                                           | 7      | 25       | 47          | 34
# Somewhat Disagree                                                                                                        | 2      | 10       | 18          | 17
# Strongly Agree                                                                                                           | 13     | 42       | 43          | 9
# Strongly Disagree                                                                                                        | 5      | 7        | 10          | 9

# %% [markdown]
# The table above shows some interesting statistics (see Appendix A for code on how this is created). **This type of data display is the only case in which code should be included in your report.**

# %% [markdown]
# ## Hypothesis Test
#
# Do some inference here. Remember to write out what you are doing and clearly explain how you are performing the test (make sure you clearly state hypotheses in words). Make sure you write out, in paragraph form, what is going on. Don't just show output! Make sure you interpret everything!

# %% [markdown]
# ## Confidence Interval
#
# The same goes for confidence intervals. Explain what you are doing. You don't need to state exactly the details of how you wrote your code (e.g.., don't need to explain what a for loop does), but you should state the parameters of the hypothesis test/confidence interval (e.g., simulate using how many repetitions, what confidence level, etc.).

# %% [markdown]
# ## Conclusion
#
# Concluding remarks go here. Make sure you tie it back in with your problem of interest from the introduction! Why are the results you found important? How can you apply this in the real world?

# %% [markdown]
# ## Appendix A: Code for Reading and Cleaning Data

# %%
import numpy as np
from datascience import *


# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plots

# This is if you want your plots to have the FiveThirtyEight style
plots.style.use('fivethirtyeight')

# %%
cah = Table.read_table('201709-CAH_PulseOfTheNation.csv')

# %% [markdown]
# ## Appendix B: Code for Hypothesis Test

# %%
# You can include multiple Appendices.
# Hypothesis test code goes here
